# %% [markdown]
# # Task -03

# %% [markdown]
# # TechnoHacks EduTech Internship

# %% [markdown]
# # Data Analytics Tasks : By Vivek Kumar

# %% [markdown]
# # Task 3 - Create a histogram or bar chart to visualize the distribution of data in a dataset

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # # Load the Iris dataset

# %% [markdown]
#  we use iris dataset.

# %%
iris_data=pd.read_csv('iris.csv',encoding='utf8')
data=iris_data.copy()

# %% [markdown]
# Show all data. which is present in iris.csv file

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.shape
# Out:
# (150, 6)

# %%
data.size
# Out:
# 900

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# it describe: mean,count,standard deviation,25%,50%,75% and max value

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# Find how many columns and how much NAN value present in the given datasets

# %%
data.isnull().sum()   # means that data is clean. there is no any NAN value
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# Data is cleaned.

# %%
sns.heatmap(data.isnull(), yticklabels=False)
# Out:
# <Axes: >

# %% [markdown]
# # Histogram

# %% [markdown]
# Draw histogram and visualize the distribution of data in a dataset

# %%
numeric_columns=data.select_dtypes(include=[float,int])
for column in numeric_columns.columns:
    bin=[1,2,3,4,5]
    plt.hist(data[column],bins=bin,alpha=0.7,label=column,edgecolor='yellow')
# Customize the plot
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histograms of Iris Dataset Columns")
plt.legend()
plt.show()

# %% [markdown]
# Draw Bar chart and visualize the distribution of data in a dataset: column name is species

# %%
# Count the occurrences of each species
species_count=data['Species'].value_counts()
print(species_count)
# Create a bar chart
plt.figure(figsize=(8, 6))  # Set the figure size
# Plot the data
species_count.plot(kind='bar',color='red',edgecolor='black')
# Add labels and title
plt.xlabel('Species')
plt.ylabel('Count')
plt.title('Distribution of Iris Species')
plt.xticks(rotation=40)

# Show the plot
plt.show()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# Draw histogram and visualize the distribution of data in a dataset

# %%
# Create histograms for each numeric feature
plt.figure(figsize=(12, 8))  # Set the figure size

# Sepal Length Histogram
plt.subplot(2, 2, 1)
plt.hist(data['SepalLengthCm'], bins=20, color='skyblue')
plt.xlabel('SepalLengthCm')
plt.ylabel('Frequency')
plt.title('Distribution of SepalLengthCm')

# Sepal Width Histogram
plt.subplot(2, 2, 2)
plt.hist(data['SepalWidthCm'], bins=20, color='lightcoral')
plt.xlabel('SepalWidthCm')
plt.ylabel('Frequency')
plt.title('Distribution of Sepal Width')

# Petal Length Histogram
plt.subplot(2, 2, 3)
plt.hist(data['PetalLengthCm'], bins=20, color='lightgreen')
plt.xlabel('PetalLengthCm')
plt.ylabel('Frequency')
plt.title('Distribution of Petal Length')

# Petal Width Histogram
plt.subplot(2, 2, 4)
plt.hist(data['PetalWidthCm'], bins=20, color='gold')
plt.xlabel('PetalWidthCm')
plt.ylabel('Frequency')
plt.title('Distribution of Petal Width')

# Adjust spacing between subplots
plt.tight_layout()

# Show the plots
plt.show()
